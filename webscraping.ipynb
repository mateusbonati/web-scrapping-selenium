# %%
#pip install selenium
#pip install webdriver-manager

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://www.mercadolivre.com.br/')
driver.maximize_window()


element = driver.find_element("xpath","/html/body/header/div/form/input")
element.send_keys('livros')

lupa = driver.find_element('xpath', '/html/body/header/div/form/button')
lupa.click()


botao_cookies = driver.find_element('xpath','/html/body/div[2]/div[1]/div[2]/button[1]')
botao_cookies.click()

botao_cep = driver.find_element('xpath','/html/body/div[3]/div/div/div[2]/div/div/div[2]/button[2]')
botao_cep.click()

lista_titulos = driver.find_elements(By.XPATH, "//h2[@class='ui-search-item__title ui-search-item__group__element shops__items-group-details shops__item-title']")
for k in range(len(lista_titulos)):
    print(lista_titulos[k].text)

precos = driver.find_elements(By.XPATH, "//span[@class='price-tag ui-search-price__part shops__price-part']")

#lista_precos = driver.find_elements(By.XPATH, "//div[@class='ui-search-price__second-line shops__price-second-line']")
#lista_precos_final = []
#for k in range(len(lista_precos)):
#    print(lista_precos[k].text)
#    real = lista_precos[k].text.split(' ')[0]
#    try:
#        centavo = lista_precos[k].text.split(' ')[3]
#    except:
#        centavo = '00'
#    preco_completo = f'R$ {real},{centavo}'
#    lista_precos_final.append(preco_completo)
#    print(preco_completo)



#df_temp = pd.DataFrame({'titulos':lista_titulos, 'precos':lista_precos_final})

driver.close()
# Out:
# /tmp/ipykernel_7298/529199943.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# Ego Transformado A Humildade Que Brota Do Evangelho
# O Gênio do Crime, de Marinho, João Carlos. Série João Carlos Marinho Editora Grupo Editorial Global, capa mole em português, 2009
# A ilha perdida, de Dupré, Maria José. Série Vaga-Lume Editora Somos Sistema de Ensino, capa mole em português, 2015
# Segredos Da Mente Milionária (os)
# A construção da maldade: Como ocorreu a destruição da segurança pública brasileira, de Motta, Roberto. Editora Faro Editorial Eireli, capa mole em português, 2022
# Café Com Deus Pai 2023 | Porções Diárias De Renovação | Juni
# Livro - Pai Rico, Pai Pobre - Robert Kiyosaki
# Diário de um banana 9: caindo na estrada, de Kinney, Jeff. Série Diário de um banana Vergara & Riba Editoras, capa dura em português, 2015
# ...

# %%
import time
import pandas as pd


driver = webdriver.Chrome(ChromeDriverManager().install())

driver.get("https://www.vivareal.com.br/")
driver.maximize_window()
time.sleep(2)

botao_alugar = driver.find_element(By.XPATH, '/html/body/div[1]/main/section[1]/section/main/div/section/form/article/div/div/button[2]')
botao_alugar.click()

time.sleep(2)

#checkbox tipo de imovel
checkbox_tipo_imovel = driver.find_element(By.XPATH, '/html/body/div[1]/main/section[1]/section/main/div/section/form/section/section[1]/div/div[2]/div[1]/button/div/div[3]')
checkbox_tipo_imovel.click()

time.sleep(2)

#checkbox apartamento
checkbox_apartamento = driver.find_element(By.XPATH, '/html/body/div[1]/main/section[1]/section/main/div/section/form/section/section[1]/div/div[2]/div[2]/div/div[1]/div[1]')
checkbox_apartamento.click()

caixa_texto = driver.find_element(By.XPATH, '/html/body/div[1]/main/section[1]/section/main/div/section/form/section/section[2]/div/div[2]/div/div/div/div/input')
time.sleep(2)
caixa_texto.send_keys("São Paulo")
time.sleep(2)

checkbox_sp = driver.find_element(By.XPATH,'/html/body/div[1]/main/section[1]/section/main/div/section/form/section/section[2]/div/div[2]/div[2]/div/div[2]/div/label')
checkbox_sp.click()
time.sleep(4)


botao_buscar = driver.find_element(By.XPATH, '/html/body/div[1]/main/section[1]/section/main/div/section/form/section/div/button')
botao_buscar.click()

df_final = pd.DataFrame()

for k in range(4):
    
    time.sleep(4)

    #get descricao apartamento
    descricoes = driver.find_elements(By.XPATH, "//span[@class='property-card__title js-cardLink js-card-title']")
    endereco = driver.find_elements(By.XPATH, "//span[@class='property-card__address']")
    preco = driver.find_elements(By.XPATH, "//div[@class='property-card_price js-property-card-prices js-property-card_price-small']")
    metros_quadrados = driver.find_elements(By.XPATH, "//span[@class='property-card_detail-value js-property-card-value property-card_detail-area js-property-card-detail-area']")
    quartos = driver.find_elements(By.XPATH, "//li[@class='property-card_detail-item property-card_detail-room js-property-detail-rooms']")

    banheiros = driver.find_elements(By.XPATH, "//li[@class='property-card_detail-item property-card_detail-bathroom js-property-detail-bathroom']")
    vagas = driver.find_elements(By.XPATH, "//li[@class='property-card_detail-item property-card_detail-garage js-property-detail-garages']")

    #text in every elem
    descricoes_text = [descricao.text for descricao in descricoes]
    endereco_text = [end.text for end in endereco]
    preco_text = [preco.text for preco in preco]
    metros_quadrados_text = [metros_quadrados.text for metros_quadrados in metros_quadrados]
    quartos_text = [quartos.text for quartos in quartos]
    banheiros_text = [banheiros.text for banheiros in banheiros]
    vagas_text = [vagas.text for vagas in vagas]

    print(len(descricoes_text))
    print(len(endereco_text))
    print(len(preco_text))
    print(len(metros_quadrados_text))
    print(len(quartos_text))
    print(len(banheiros_text))
    print(len(vagas_text))

    df_temp = pd.DataFrame({'descricao': descricoes_text, 'endereco': endereco_text, 'preco': preco_text, 'metros_quadrados': metros_quadrados_text, 'quartos': quartos_text, 'banheiros': banheiros_text, 'vagas': vagas_text})
    
    df_final = pd.concat([df_final, df_temp], axis=0)
    #click button next page
    next_page = driver.find_element(By.XPATH, "/html/body/main/div[2]/div[1]/section/div[2]/div[2]/div/ul/li[9]/button")

    #js code to click button next page
    driver.execute_script("arguments[0].click();", next_page)


driver.close()

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
#remove /mês from preco
df_final['preco'] = df_final['preco'].str.replace('/mês', '')

#keep only number in quartos
df_final['quartos'] = df_final['quartos'].str.replace('Quartos', '')
df_final['quartos'] = df_final['quartos'].str.replace('Quarto', '')
df_final['banheiros'] = df_final['quartos'].str.replace('Banheiros', '')
df_final['banheiros'] = df_final['quartos'].str.replace('Banheiro', '')
df_final['vagas'] = df_final['quartos'].str.replace('Vagas', '')
df_final['vagas'] = df_final['quartos'].str.replace('Vaga', '')

df_final.rename(columns={'preco': 'preco_mensal'}, inplace=True)
df_final.reset_index(drop=True, inplace=True)
# Out:
# /tmp/ipykernel_7298/3823264803.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# 36
# 36
# 0
# 0
# 0
# 0
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7298/3823264803.py in <module>
#      70     print(len(vagas_text))
#      71
# ---> 72     df_temp = pd.DataFrame({'descricao': descricoes_text, 'endereco': endereco_text, 'preco': preco_text, 'metros_quadrados': metros_quadrados_text, 'quartos': quartos_text, 'banheiros': banheiros_text, 'vagas': vagas_text})
#      73
#      74     df_final = pd.concat([df_final, df_temp], axis=0)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
# ...
